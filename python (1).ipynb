# %% [markdown]
# PYTHON BASICS

# %% [markdown]
# Q1. Explain the keyfeatures of python that make it a popular choice for programming
# _Python versality has made it a favorite among develpers of all skill levels from begginers to expert python is compiled and interpreted oriented .high level programming language with dynamic semantic.fetures of python are given below
#
# 1.   object oriented
# 2.   dynamically typed
# 3.   large standered library
# 4.   free and open source
# 5.   interpreted language
# 6.   easy to learn and use
#
# Q2. Describe the role of predefined keywords in python and provide example of how they are used in a program.
# _ predefined keywords in python are reserved words that have special meaning to the python interpreter.
#
# COMMON PYTHON KEYWORDS AND THEIR ROLES
# 1. DEF-to define function
# 2. FOR ,WHILE- for loops
# 3. IF,ELSE,ELIF- for conditional statement
# 4. IMPORT- to import module
# 5. TRUE,FALSE- boolean value
# 6. AND OR NOT-logical operator

# %%
is_raining = True
type (is_raining)
# Out:
# bool

# %% [markdown]
# Q3. Compare and contrast mutable and immutable objects in python with example.
# _ In python ,mutable and immutable object arevtwo fundamental type that determine whetherthe value of an object can be edit after it is created.
#  MUTABLE OBJECT
#
# *DEFINATION :object whose value can be edit after creation.
# *EXAMPLE- list,dict,set.

# %% [markdown]
# IMMUTABLE OBJECT
# *DEFINATION:object whose value cannot be edit once they are created.
# *EXAMPLE-int,float,tuple,byte.

# %%
name = "alice"
name = name.replace("a", "n")
print(name)
# Out:
# nlice

# %% [markdown]
# (even through we edit the string, a new string created. the original Alice didnt edited becaue strungs are immutable.)

# %% [markdown]
# Q4. Discuss the diffrent types of operators in python and provide examples of how they are used.
# _python operstor-python operator are special keywords that are used to perform operation on value or variable.
# *ARITHMATIC OPERATOR-+,-,*,/,%,**
# *COMPARISON OPERATOR-==,!=,>,<,>=,<=
# *LOGICAL OPERATOR-Logical AND
#                  -Logical OR
#                  -Logical NOT (not)
# *BITWISE OPERATOR-AND(&),
#                  -OR(|),
#                  -NOT(-),
#                  -XOR(^),
#                  -(<<),
#                  -(>>)
# *ASSINGMENT OPERATOR- (=),(+=),(-=),(*=),(/=)
# *MEMBERSHIP OPERATOR-IN
#                     -NOT
# *IDENTITY OPERATOR-IS
#                   -IS NOT

# %% [markdown]
# ARITHMATIC OPERATOR -

# %%
a = 10
b = 5
print(a+b)
# Out:
# 15

# %%
print(a-b)
# Out:
# 5

# %%
print (a*b)
# Out:
# 50

# %%
print(a/b)
# Out:
# 2.0

# %% [markdown]
# LOGICAL OPERATOR `

# %%
a = 10
b = 5
print(a>5 and b<10)
# Out:
# True

# %%
print(a<5 or b<10)
# Out:
# True

# %%
print(not(a>5))
# Out:
# False

# %% [markdown]
# Q5. Explain the concept type casting in python with example
# _  type casting in python mean converting one data to another
# * type of casting : 1. implicit type casting( autocrated by python)
#                     2.explicit type casting (manually done by the programmer)

# %%
a = 5
b = 2.0
result =a + b
print(result)
# Out:
# 7.0

# %%
print(type(result))
# Out:
# <class 'float'>

# %%
x = 100
y = int (x)
print (y+50)
# Out:
# 150

# %%
print(type(y))
# Out:
# <class 'int'>

# %% [markdown]
#  Q6. How do conditional statement work in python ? give example
#  _in python let you make decision in your code based on certain condition.

# %%
age = 18

if age < 18:
  print ("you are minor.")
elif age == 18 :
  print("you become an adult!")
else:
   print("you are an adult")
# Out:
# you become an adult!

# %% [markdown]
# Q7. Describe the diffrent type of loops in python and their use cases with example
# _in python there are 1. for loop
#                      2.bwhile loop

# %%
for i in range(1, 6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i <= 5:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# * run as lon as condition is true
